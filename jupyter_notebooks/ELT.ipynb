# %% [markdown]
# # ELT

# %% [markdown]
# ## Objectives
#
# * Load raw data, inspect and clean missing data and duplicated rows. Check data types for any issues.
# * To prepare data for subssampling
#
# ## Inputs
#
# * The dataset, "US_Accidents_March23_sampled_500k.csv", which is saved locally in "Data/Raw/US_Accidents"
#
# ## Outputs
#
# * Cleaned csv file "US_Accidents_For_Subsampling.csv"
#
# ## Steps Carried Out
#
# * Load data
# * Checked data types
# * Dropped unnecessary columns
# * Dropped rows with missing values
# * Dropped rows with "N/A Precipitation"
# * Checked "ID" values are unque before dropping
# * Dropped duplicated rows
# * Save to csv file

# %% [markdown]
# ---

# %% [markdown]
# # Change working directory

# %% [markdown]
# * We are assuming you will store the notebooks in a subfolder, therefore when running the notebook in the editor, you will need to change the working directory

# %% [markdown]
# We need to change the working directory from its current folder to its parent folder
# * We access the current directory with os.getcwd()

# %%
import os
current_dir = os.getcwd()
current_dir
# Out:
# 'c:\\Users\\sonia\\Documents\\VS Studio Projects\\US_Accidents_ML_Project\\jupyter_notebooks'

# %% [markdown]
# We want to make the parent of the current directory the new current directory
# * os.path.dirname() gets the parent directory
# * os.chir() defines the new current directory

# %%
os.chdir(os.path.dirname(current_dir))
print("You set a new current directory")
# Out:
# You set a new current directory

# %% [markdown]
# Confirm the new current directory

# %%
current_dir = os.getcwd()
current_dir
# Out:
# 'c:\\Users\\sonia\\Documents\\VS Studio Projects\\US_Accidents_ML_Project'

# %% [markdown]
# ---

# %% [markdown]
# ## Required Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ---

# %% [markdown]
# ## Load Raw Dataset

# %% [markdown]
# I will use Pandas to load the data into a DataFrame (df).

# %%
df = pd.read_csv("Data/Raw/US_Accidents/US_Accidents_March23_sampled_500k.csv")
pd.set_option("display.max_columns", None)
df
# Out:
#                ID   Source  Severity                     Start_Time  \
# 0       A-2047758  Source2         2            2019-06-12 10:10:56
# 1       A-4694324  Source1         2  2022-12-03 23:37:14.000000000
# 2       A-5006183  Source1         2  2022-08-20 13:13:00.000000000
# 3       A-4237356  Source1         2            2022-02-21 17:43:04
# 4       A-6690583  Source1         2            2020-12-04 01:46:00
# ...           ...      ...       ...                            ...
# 499995  A-6077227  Source1         2            2021-12-15 07:30:00
# 499996  A-6323243  Source1         2            2021-12-19 16:25:00
# 499997  A-3789256  Source1         2            2022-04-13 19:28:29
# 499998  A-7030381  Source1         3            2020-05-15 17:20:56
# 499999  A-5438901  Source1         2            2022-04-02 23:23:13
#
#                              End_Time  Start_Lat   Start_Lng    End_Lat  \
# 0                 2019-06-12 10:55:58  30.641211  -91.153481        NaN
# 1       2022-12-04 01:56:53.000000000  38.990562  -77.399070  38.990037
# 2       2022-08-20 15:22:45.000000000  34.661189 -120.492822  34.661189
# 3                 2022-02-21 19:43:23  43.680592  -92.993317  43.680574
# 4                 2020-12-04 04:13:09  35.395484 -118.985176  35.395476
# ...                               ...        ...         ...        ...
# 499995            2021-12-15 07:50:30  45.522510 -123.084104  45.520225
# 499996            2021-12-19 17:40:37  26.702570  -80.111169  26.703141
# 499997            2022-04-13 21:33:44  34.561862 -112.259620  34.566822
# 499998            2020-05-15 17:50:56  38.406680  -78.619310  38.406680
# 499999            2022-04-03 00:49:48  35.069358  -85.234410  35.070505
#
#            End_Lng  Distance(mi)  \
# 0              NaN         0.000
# 1       -77.398282         0.056
# 2      -120.492442         0.022
# 3       -92.972223         1.054
# 4      -118.985995         0.046
# ...            ...           ...
# 499995 -123.084211         0.158
# 499996  -80.111133         0.040
# 499997 -112.267150         0.549
# 499998  -78.619310         0.000
# 499999  -85.233836         0.086
#
#                                               Description            Street  \
# 0       Accident on LA-19 Baker-Zachary Hwy at Lower Z...        Highway 19
# 1       Incident on FOREST RIDGE DR near PEPPERIDGE PL...   Forest Ridge Dr
# 2       Accident on W Central Ave from Floradale Ave t...     Floradale Ave
# 3       Incident on I-90 EB near REST AREA Drive with ...        14th St NW
# 4       RP ADV THEY LOCATED SUSP VEH OF 20002 - 726 CR...        River Blvd
# ...                                                   ...               ...
# 499995  Stationary traffic on OR-47 from NW Martin Rd ...         Quince St
# 499996  Incident on MILITARY TRL near WESTGATE AVE Dri...    N Military Trl
# 499997  Crash on the right shoulder on E SR-69 Northbo...           E AZ-69
# 499998         At US-340/S Stuart Ave - Serious accident.   W Spotswood Trl
# 499999  Incident on NEW JERSEY AVE near NEW YORK AVE E...      New York Ave
#
#                    City            County State     Zipcode Country  \
# 0               Zachary  East Baton Rouge    LA  70791-4610      US
# 1              Sterling           Loudoun    VA  20164-2813      US
# 2                Lompoc     Santa Barbara    CA       93436      US
# 3                Austin             Mower    MN       55912      US
# 4           Bakersfield              Kern    CA  93305-2649      US
# ...                 ...               ...   ...         ...     ...
# 499995     Forest Grove        Washington    OR  97116-2174      US
# 499996  West Palm Beach        Palm Beach    FL  33409-4712      US
# 499997            Dewey           Yavapai    AZ       86327      US
# 499998           Elkton        Rockingham    VA       22827      US
# 499999      Chattanooga          Hamilton    TN  37406-2132      US
#
#            Timezone Airport_Code    Weather_Timestamp  Temperature(F)  \
# 0        US/Central         KBTR  2019-06-12 09:53:00            77.0
# 1        US/Eastern         KIAD  2022-12-03 23:52:00            45.0
# 2        US/Pacific         KLPC  2022-08-20 12:56:00            68.0
# 3        US/Central         KAUM  2022-02-21 17:35:00            27.0
# 4        US/Pacific         KBFL  2020-12-04 01:54:00            42.0
# ...             ...          ...                  ...             ...
# 499995   US/Pacific         KHIO  2021-12-15 07:14:00            40.0
# 499996   US/Eastern         KPBI  2021-12-19 16:53:00            78.0
# 499997  US/Mountain         KPRC  2022-04-13 19:53:00            52.0
# 499998   US/Eastern         KSHD  2020-05-15 17:15:00            82.0
# 499999   US/Eastern         KCHA  2022-04-02 23:53:00            50.0
#
#         Wind_Chill(F)  Humidity(%)  Pressure(in)  Visibility(mi)  \
# 0                77.0         62.0         29.92            10.0
# 1                43.0         48.0         29.91            10.0
# 2                68.0         73.0         29.79            10.0
# 3                15.0         86.0         28.49            10.0
# 4                42.0         34.0         29.77            10.0
# ...               ...          ...           ...             ...
# 499995           32.0         77.0         29.55            10.0
# 499996           78.0         87.0         29.94            10.0
# 499997           52.0         12.0         24.94            10.0
# 499998           82.0         38.0         28.70            10.0
# 499999           50.0         66.0         29.29            10.0
#
#        Wind_Direction  Wind_Speed(mph)  Precipitation(in) Weather_Condition  \
# 0                  NW              5.0               0.00              Fair
# 1                   W              5.0               0.00              Fair
# 2                   W             13.0               0.00              Fair
# 3                 ENE             15.0               0.00        Wintry Mix
# 4                CALM              0.0               0.00              Fair
# ...               ...              ...                ...               ...
# 499995            SSE             15.0               0.01        Light Rain
# 499996            SSE             13.0               0.01     Partly Cloudy
# 499997            WSW             12.0               0.00              Fair
# 499998            SSW             14.0               0.00              Fair
# 499999           CALM              0.0               0.00              Fair
#
#         Amenity   Bump  Crossing  Give_Way  Junction  No_Exit  Railway  \
# 0         False  False     False     False     False    False    False
# 1         False  False     False     False     False    False    False
# 2         False  False     False     False     False    False    False
# 3         False  False     False     False     False    False    False
# 4         False  False     False     False     False    False    False
# ...         ...    ...       ...       ...       ...      ...      ...
# 499995    False  False     False     False     False    False    False
# 499996    False  False     False     False     False    False    False
# 499997    False  False      True      True     False    False    False
# 499998    False  False     False     False     False    False    False
# 499999    False  False     False     False     False    False    False
#
#         Roundabout  Station   Stop  Traffic_Calming  Traffic_Signal  \
# 0            False    False  False            False            True
# 1            False    False  False            False           False
# 2            False    False  False            False            True
# 3            False    False  False            False           False
# 4            False    False  False            False           False
# ...            ...      ...    ...              ...             ...
# 499995       False    False  False            False           False
# 499996       False    False  False            False           False
# 499997       False    False  False            False            True
# 499998       False    False  False            False            True
# 499999       False    False  False            False           False
#
#         Turning_Loop Sunrise_Sunset Civil_Twilight Nautical_Twilight  \
# 0              False            Day            Day               Day
# 1              False          Night          Night             Night
# 2              False            Day            Day               Day
# 3              False            Day            Day               Day
# 4              False          Night          Night             Night
# ...              ...            ...            ...               ...
# 499995         False          Night            Day               Day
# 499996         False            Day            Day               Day
# 499997         False          Night          Night               Day
# 499998         False            Day            Day               Day
# 499999         False          Night          Night             Night
#
#        Astronomical_Twilight
# 0                        Day
# 1                      Night
# 2                        Day
# 3                        Day
# 4                      Night
# ...                      ...
# 499995                   Day
# 499996                   Day
# 499997                   Day
# 499998                   Day
# 499999                 Night
#
# [500000 rows x 46 columns]

# %% [markdown]
# I can see this is a large dataset with 500,000 rows and 46 columns.

# %% [markdown]
# ---

# %% [markdown]
# ## Inital Inspection and Cleaning

# %% [markdown]
# I will look at what data types are present and if there are missing values.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 46 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   ID                     500000 non-null  object
#  1   Source                 500000 non-null  object
#  2   Severity               500000 non-null  int64
#  3   Start_Time             500000 non-null  object
#  4   End_Time               500000 non-null  object
#  5   Start_Lat              500000 non-null  float64
#  6   Start_Lng              500000 non-null  float64
#  7   End_Lat                279623 non-null  float64
#  8   End_Lng                279623 non-null  float64
#  9   Distance(mi)           500000 non-null  float64
#  10  Description            499999 non-null  object
#  11  Street                 499309 non-null  object
#  12  City                   499981 non-null  object
#  13  County                 500000 non-null  object
#  14  State                  500000 non-null  object
#  15  Zipcode                499884 non-null  object
#  16  Country                500000 non-null  object
#  17  Timezone               499493 non-null  object
#  18  Airport_Code           498554 non-null  object
#  19  Weather_Timestamp      492326 non-null  object
#  20  Temperature(F)         489534 non-null  float64
#  21  Wind_Chill(F)          370983 non-null  float64
#  22  Humidity(%)            488870 non-null  float64
#  23  Pressure(in)           491072 non-null  float64
#  24  Visibility(mi)         488709 non-null  float64
#  25  Wind_Direction         488803 non-null  object
#  26  Wind_Speed(mph)        463013 non-null  float64
#  27  Precipitation(in)      357384 non-null  float64
#  28  Weather_Condition      488899 non-null  object
#  29  Amenity                500000 non-null  bool
#  30  Bump                   500000 non-null  bool
#  31  Crossing               500000 non-null  bool
#  32  Give_Way               500000 non-null  bool
#  33  Junction               500000 non-null  bool
#  34  No_Exit                500000 non-null  bool
#  35  Railway                500000 non-null  bool
#  36  Roundabout             500000 non-null  bool
#  37  Station                500000 non-null  bool
#  38  Stop                   500000 non-null  bool
#  39  Traffic_Calming        500000 non-null  bool
#  40  Traffic_Signal         500000 non-null  bool
#  41  Turning_Loop           500000 non-null  bool
#  42  Sunrise_Sunset         498517 non-null  object
#  43  Civil_Twilight         498517 non-null  object
#  44  Nautical_Twilight      498517 non-null  object
#  45  Astronomical_Twilight  498517 non-null  object
# dtypes: bool(13), float64(12), int64(1), object(20)
# memory usage: 132.1+ MB

# %% [markdown]
# I can see there is a mixture of objects, booleans, floats and integers. At this point, all of the data types appear consistent with expectations.
#
# I can also see that there is missing data from many of the variables. My plan is to first drop variables that I'm sure I won't need, and then delete rows with missing values, before looking for duplicates. I have chosen to delete rows rather than impute, because the dataset is far larger than needed, and I will subsample to make a smaller dataset of ~ 10,000 instances. In this circumstance, I believe it makes sense to preserve complete data and drop incomplete data.

# %%
df_clean = df.drop(columns=[
    "Source", "End_Lat", "End_Lng", "Description", "Street", "Zipcode", "Country",
    "Weather_Timestamp", "Civil_Twilight", "Nautical_Twilight", "Astronomical_Twilight"
])

# %% [markdown]
# I choose to drop these variables because I believe they will either be irrelevant or potentially lead to overfitting of the model.

# %%
df_clean.shape
# Out:
# (500000, 35)

# %% [markdown]
# I can see we have lost 11 columns.

# %% [markdown]
# I will look at how many missing values are in each column before dropping them.

# %%
df_clean.isna().sum()
# Out:
# ID                        0
# Severity                  0
# Start_Time                0
# End_Time                  0
# Start_Lat                 0
# Start_Lng                 0
# Distance(mi)              0
# City                     19
# County                    0
# State                     0
# Timezone                507
# Airport_Code           1446
# Temperature(F)        10466
# Wind_Chill(F)        129017
# Humidity(%)           11130
# Pressure(in)           8928
# Visibility(mi)        11291
# Wind_Direction        11197
# Wind_Speed(mph)       36987
# Precipitation(in)    142616
# Weather_Condition     11101
# Amenity                   0
# Bump                      0
# Crossing                  0
# Give_Way                  0
# Junction                  0
# No_Exit                   0
# Railway                   0
# Roundabout                0
# Station                   0
# Stop                      0
# Traffic_Calming           0
# Traffic_Signal            0
# Turning_Loop              0
# Sunrise_Sunset         1483
# dtype: int64

# %% [markdown]
# I can see that I have missing values for "City", "Timezone", "Airport_Code", "Sunrise_Sunset" and all weather condition related variables. I will drop all rows with missing data.

# %%
df_clean = df_clean.dropna()

print(f"After dropping missing values: {df_clean.shape}")
# Out:
# After dropping missing values: (337617, 35)

# %% [markdown]
# I also noted that in "Weather_Condition", the term "N/A Precipitation" appears which is a placeholder for missing data. I will check how many rows contain this holder before cleaning them.

# %%
df_clean["Weather_Condition"].value_counts().get("N/A Precipitation", 0)
# Out:
# 187

# %%
df_clean = df_clean[df_clean["Weather_Condition"] != "N/A Precipitation"]
df_clean["Weather_Condition"].value_counts().get("N/A Precipitation", 0)
# Out:
# 0

# %% [markdown]
# Now I will check for duplicated rows. First, I will ensure all "ID" values are unique, and then drop this column.

# %%
df_clean["ID"].is_unique
# Out:
# True

# %%
df_clean = df_clean.drop(columns=["ID"])
df_clean.head()
# Out:
#    Severity                     Start_Time                       End_Time  \
# 0         2            2019-06-12 10:10:56            2019-06-12 10:55:58
# 1         2  2022-12-03 23:37:14.000000000  2022-12-04 01:56:53.000000000
# 2         2  2022-08-20 13:13:00.000000000  2022-08-20 15:22:45.000000000
# 3         2            2022-02-21 17:43:04            2022-02-21 19:43:23
# 4         2            2020-12-04 01:46:00            2020-12-04 04:13:09
#
#    Start_Lat   Start_Lng  Distance(mi)         City            County State  \
# 0  30.641211  -91.153481         0.000      Zachary  East Baton Rouge    LA
# 1  38.990562  -77.399070         0.056     Sterling           Loudoun    VA
# 2  34.661189 -120.492822         0.022       Lompoc     Santa Barbara    CA
# 3  43.680592  -92.993317         1.054       Austin             Mower    MN
# 4  35.395484 -118.985176         0.046  Bakersfield              Kern    CA
#
#      Timezone Airport_Code  Temperature(F)  Wind_Chill(F)  Humidity(%)  \
# 0  US/Central         KBTR            77.0           77.0         62.0
# 1  US/Eastern         KIAD            45.0           43.0         48.0
# 2  US/Pacific         KLPC            68.0           68.0         73.0
# 3  US/Central         KAUM            27.0           15.0         86.0
# 4  US/Pacific         KBFL            42.0           42.0         34.0
#
#    Pressure(in)  Visibility(mi) Wind_Direction  Wind_Speed(mph)  \
# 0         29.92            10.0             NW              5.0
# 1         29.91            10.0              W              5.0
# 2         29.79            10.0              W             13.0
# 3         28.49            10.0            ENE             15.0
# 4         29.77            10.0           CALM              0.0
#
#    Precipitation(in) Weather_Condition  Amenity   Bump  Crossing  Give_Way  \
# 0                0.0              Fair    False  False     False     False
# 1                0.0              Fair    False  False     False     False
# 2                0.0              Fair    False  False     False     False
# 3                0.0        Wintry Mix    False  False     False     False
# 4                0.0              Fair    False  False     False     False
#
#    Junction  No_Exit  Railway  Roundabout  Station   Stop  Traffic_Calming  \
# 0     False    False    False       False    False  False            False
# 1     False    False    False       False    False  False            False
# 2     False    False    False       False    False  False            False
# 3     False    False    False       False    False  False            False
# 4     False    False    False       False    False  False            False
#
#    Traffic_Signal  Turning_Loop Sunrise_Sunset
# 0            True         False            Day
# 1           False         False          Night
# 2            True         False            Day
# 3           False         False            Day
# 4           False         False          Night

# %% [markdown]
# Now I will check for duplicated rows.

# %%
df_clean[df_clean.duplicated()]
# Out:
#         Severity           Start_Time             End_Time  Start_Lat  \
# 45814          2  2022-01-05 05:35:58  2022-01-05 07:05:58  38.842436
# 51246          1  2020-05-03 21:13:00  2020-05-04 01:00:00  34.773870
# 52663          2  2020-12-06 19:06:22  2020-12-06 22:27:25  29.766078
# 84440          3  2020-04-14 15:19:27  2020-04-14 16:04:27  40.833020
# 84491          2  2020-12-21 21:55:30  2020-12-21 23:33:00  38.802161
# ...          ...                  ...                  ...        ...
# 496472         2  2021-08-12 14:03:00  2021-08-12 15:46:12  39.534239
# 497673         3  2020-04-29 16:30:52  2020-04-29 16:45:52  42.257320
# 498399         2  2020-10-31 02:57:00  2020-10-31 05:52:19  25.528310
# 498530         2  2020-12-19 05:38:00  2020-12-19 09:45:00  34.955238
# 499486         2  2021-06-09 18:09:00  2021-06-09 22:35:32  39.673476
#
#          Start_Lng  Distance(mi)          City                County State  \
# 45814   -77.007942         0.936    Washington  District of Columbia    DC
# 51246   -79.329460         0.000        Maxton               Robeson    NC
# 52663   -95.277722         0.222       Houston                Harris    TX
# 84440   -73.146390         0.000     Nesconset               Suffolk    NY
# 84491   -77.510604         0.692      Manassas        Prince William    VA
# ...            ...           ...           ...                   ...   ...
# 496472 -121.575122         0.089      Oroville                 Butte    CA
# 497673  -71.011320         0.000        Quincy               Norfolk    MA
# 498399  -80.392874         1.009     Homestead            Miami-Dade    FL
# 498530  -78.757721         0.305  Fayetteville            Cumberland    NC
# 499486 -121.627024         0.227      Oroville                 Butte    CA
#
#           Timezone Airport_Code  Temperature(F)  Wind_Chill(F)  Humidity(%)  \
# 45814   US/Eastern         KDCA            32.0           24.0         79.0
# 51246   US/Eastern         KMEB            78.0           78.0         46.0
# 52663   US/Central         KHOU            58.0           58.0         53.0
# 84440   US/Eastern         KISP            54.0           54.0         34.0
# 84491   US/Eastern         KHEF            40.0           40.0         97.0
# ...            ...          ...             ...            ...          ...
# 496472  US/Pacific         KOVE            91.0           91.0         39.0
# 497673  US/Eastern         KMQE            54.0           54.0         37.0
# 498399  US/Eastern         KHST            78.0           78.0         96.0
# 498530  US/Eastern         KFAY            29.0           29.0         82.0
# 499486  US/Pacific         KOVE            77.0           77.0         22.0
#
#         Pressure(in)  Visibility(mi) Wind_Direction  Wind_Speed(mph)  \
# 45814          30.09            10.0              S             10.0
# 51246          29.58            10.0            SSW             10.0
# 52663          30.01            10.0            WNW              7.0
# 84440          29.90            10.0            WNW              5.0
# 84491          29.53            10.0           CALM              0.0
# ...              ...             ...            ...              ...
# 496472         29.69            10.0              W              6.0
# 497673         30.26            10.0              E             12.0
# 498399         29.98            10.0            NNW              3.0
# 498530         30.22            10.0           CALM              0.0
# 499486         29.82            10.0            SSE             17.0
#
#         Precipitation(in) Weather_Condition  Amenity   Bump  Crossing  \
# 45814                 0.0            Cloudy    False  False     False
# 51246                 0.0              Fair    False  False     False
# 52663                 0.0              Fair    False  False     False
# 84440                 0.0     Mostly Cloudy    False  False      True
# 84491                 0.0            Cloudy    False  False     False
# ...                   ...               ...      ...    ...       ...
# 496472                0.0              Fair    False  False     False
# 497673                0.0            Cloudy    False  False     False
# 498399                0.0              Fair    False  False     False
# 498530                0.0              Fair    False  False     False
# 499486                0.0              Fair    False  False     False
#
#         Give_Way  Junction  No_Exit  Railway  Roundabout  Station   Stop  \
# 45814      False     False    False    False       False    False  False
# 51246      False     False    False    False       False    False  False
# 52663      False     False    False    False       False    False  False
# 84440      False     False    False    False       False    False  False
# 84491      False     False    False    False       False    False  False
# ...          ...       ...      ...      ...         ...      ...    ...
# 496472     False     False    False    False       False    False  False
# 497673     False     False    False    False       False    False  False
# 498399     False     False    False    False       False    False  False
# 498530     False     False    False    False       False    False  False
# 499486     False     False    False    False       False    False  False
#
#         Traffic_Calming  Traffic_Signal  Turning_Loop Sunrise_Sunset
# 45814             False           False         False          Night
# 51246             False           False         False          Night
# 52663             False           False         False          Night
# 84440             False           False         False            Day
# 84491             False           False         False          Night
# ...                 ...             ...           ...            ...
# 496472            False           False         False            Day
# 497673            False            True         False            Day
# 498399            False           False         False          Night
# 498530            False           False         False          Night
# 499486            False           False         False            Day
#
# [458 rows x 34 columns]

# %% [markdown]
# I will remove these duplicates.

# %%
df_clean = df_clean.drop_duplicates()
df_clean.shape
# Out:
# (336972, 34)

# %% [markdown]
# I will have a last check of the DataFrame before saving df_clean as a csv file.

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 336972 entries, 0 to 499999
# Data columns (total 34 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Severity           336972 non-null  int64
#  1   Start_Time         336972 non-null  object
#  2   End_Time           336972 non-null  object
#  3   Start_Lat          336972 non-null  float64
#  4   Start_Lng          336972 non-null  float64
#  5   Distance(mi)       336972 non-null  float64
#  6   City               336972 non-null  object
#  7   County             336972 non-null  object
#  8   State              336972 non-null  object
#  9   Timezone           336972 non-null  object
#  10  Airport_Code       336972 non-null  object
#  11  Temperature(F)     336972 non-null  float64
#  12  Wind_Chill(F)      336972 non-null  float64
#  13  Humidity(%)        336972 non-null  float64
#  14  Pressure(in)       336972 non-null  float64
#  15  Visibility(mi)     336972 non-null  float64
#  16  Wind_Direction     336972 non-null  object
#  17  Wind_Speed(mph)    336972 non-null  float64
#  18  Precipitation(in)  336972 non-null  float64
#  19  Weather_Condition  336972 non-null  object
#  20  Amenity            336972 non-null  bool
#  21  Bump               336972 non-null  bool
#  22  Crossing           336972 non-null  bool
#  23  Give_Way           336972 non-null  bool
#  24  Junction           336972 non-null  bool
#  25  No_Exit            336972 non-null  bool
#  26  Railway            336972 non-null  bool
#  27  Roundabout         336972 non-null  bool
#  28  Station            336972 non-null  bool
#  29  Stop               336972 non-null  bool
#  30  Traffic_Calming    336972 non-null  bool
#  31  Traffic_Signal     336972 non-null  bool
#  32  Turning_Loop       336972 non-null  bool
#  33  Sunrise_Sunset     336972 non-null  object
# dtypes: bool(13), float64(10), int64(1), object(10)
# memory usage: 60.7+ MB

# %% [markdown]
# ---

# %% [markdown]
# ## Save to CSV

# %% [markdown]
# df_clean will be saved to csv file and used for subsampling next.

# %%
df_clean.to_csv("Data/Cleaned/US_Accidents_For_Subsampling.csv", index=False)

# %% [markdown]
# ---

# %% [markdown]
# ## Conclusion and Next Steps

# %% [markdown]
# * The dataset has been cleaned of missing values and duplicated rows
# * Data types have been checked
# * The data is ready for subsampling to derive a dataset of ~10,000 instances and balanced classes
